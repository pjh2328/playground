# %%
# !pip -q install langchain_experimental langchain_core
# !pip -q install google-generativeai==0.3.1
# !pip -q install google-ai-generativelanguage==0.4.0
# !pip -q install langchain-google-genai

# %%
pip install pypdf

# %%
pip install PyPDFLoader

# %%
pip install sentence-transformers
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl.metadata (11 kB)
# Collecting transformers<5.0.0,>=4.32.0 (from sentence-transformers)
#   Downloading transformers-4.37.2-py3-none-any.whl.metadata (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers) (1.1.3)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers) (1.11.2)
# Collecting nltk (from sentence-transformers)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 35.9 MB/s eta 0:00:00a 0:00:01
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers)
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Pillow in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers) (10.0.0)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.12.3)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.15.1->sentence-transformers)
#   Downloading fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.0.3)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.32.0->sentence-transformers)
#   Downloading regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 6.0 MB/s eta 0:00:00
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.32.0->sentence-transformers)
#   Downloading tokenizers-0.15.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.32.0->sentence-transformers)
#   Downloading safetensors-0.4.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 21.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 35.7 MB/s eta 0:00:00
# Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 34.9 MB/s eta 0:00:0000:0100:01m
# Downloading sentencepiece-0.1.99-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.1 MB/s eta 0:00:00
# Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 19.5 MB/s eta 0:00:00
# Downloading regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 20.1 MB/s eta 0:00:00
# Downloading safetensors-0.4.2-cp311-cp311-macosx_11_0_arm64.whl (393 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.4/393.4 kB 24.8 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.5 MB/s eta 0:00:00a 0:00:01
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# Installing collected packages: sentencepiece, safetensors, regex, fsspec, nltk, huggingface-hub, tokenizers, transformers, sentence-transformers
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# Successfully installed fsspec-2024.2.0 huggingface-hub-0.20.3 nltk-3.8.1 regex-2023.12.25 safetensors-0.4.2 sentence-transformers-2.3.1 sentencepiece-0.1.99 tokenizers-0.15.2 transformers-4.37.2
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# Collecting chromadb
#   Downloading chromadb-0.4.22-py3-none-any.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: requests>=2.28 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (2.6.1)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.109.2-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.27.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.22.5 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.24.3)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.4.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (4.9.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp311-cp311-macosx_10_15_universal2.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (4.2 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.60.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl.metadata (9.5 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=19.0 in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (23.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi>=14.05.14 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2023.5.7)
# Requirement already satisfied: six>=1.9.0 in /Users/jaehyeongpark/Library/Python/3.11/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/jaehyeongpark/Library/Python/3.11/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.21.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.6.2)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.16)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (4.23.4)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.60.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl.metadata (5.9 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.15.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /opt/homebrew/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/homebrew/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.9 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.12.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.16.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/homebrew/lib/python3.11/site-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (4.0.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.0)
# Downloading chromadb-0.4.22-py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.0/509.0 kB 12.1 MB/s eta 0:00:00a 0:00:01
# Downloading chroma_hnswlib-0.7.3-cp311-cp311-macosx_11_0_arm64.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.7/198.7 kB 33.0 MB/s eta 0:00:00
# Downloading bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.5/528.5 kB 6.4 MB/s eta 0:00:00a 0:00:01m
# Downloading build-1.0.3-py3-none-any.whl (18 kB)
# Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 10.1 MB/s eta 0:00:00
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.9 MB/s eta 0:00:00a 0:00:01
# Downloading mmh3-4.1.0-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading onnxruntime-1.17.0-cp311-cp311-macosx_11_0_universal2.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 15.9 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 8.0 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.4 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl (28 kB)
# Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 13.6 MB/s eta 0:00:00
# Downloading posthog-3.4.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 6.3 MB/s eta 0:00:00
# Downloading pulsar_client-3.4.0-cp311-cp311-macosx_10_15_universal2.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 32.6 MB/s eta 0:00:00 0:00:01
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 9.9 MB/s eta 0:00:00
# Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.6 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 20.0 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 16.3 MB/s eta 0:00:00
# Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 41.8 MB/s eta 0:00:00
# Downloading watchfiles-0.21.0-cp311-cp311-macosx_11_0_arm64.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.2/418.2 kB 28.8 MB/s eta 0:00:00
# Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 19.9 MB/s eta 0:00:00
# Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=1199abf7778996ed1cbc86392f8536c8b64adc881b4ce7b4b0a675f2273d3a10
#   Stored in directory: /Users/jaehyeongpark/Library/Caches/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, typer, python-dotenv, pyproject_hooks, pulsar-client, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, build, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 build-1.0.3 chroma-hnswlib-0.7.3 chromadb-0.4.22 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.109.2 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-6.11.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.0 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 posthog-3.4.1 pulsar-client-3.4.0 pypika-0.48.9 pyproject_hooks-1.0.0 python-dotenv-1.0.1 starlette-0.36.3 typer-0.9.0 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.11/site-packages (24.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.11.17.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pyparsing-3.1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/Jinja2-3.1.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pytz-2023.3.post1.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

genai.configure(api_key='AIzaSyBJep_00dpD76qfo-sbFzaR19T2KcF5YVk')

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("한국 서울 주택 시장 동향에 대해서 도표로 알려주세요")
Markdown(response.text)
# Out:
# **한국 서울 주택 시장 동향 도표**
#
# **주택 가격:**
#
# * [그림 1] 서울 평균 주택 가격 추이
#
# **거래량:**
#
# * [그림 2] 서울 주택 거래량 추이
#
# **공급:**
#
# * [그림 3] 서울 신규 주택 공급량 추이
#
# **매매 대 임대 비율:**
#
# * [그림 4] 서울 매매 대 임대 비율 추이
#
# **임대료:**
#
# * [그림 5] 서울 평균 임대료 추이
#
# **투자수익율:**
#
# * [그림 6] 서울 주택 투자수익율 추이
#
# **기타 주요 동향:**
#
# * 저금리로 인한 주택 수요 증가
# * 공급 부족으로 인한 가격 상승
# * 정부 정책 변화로 인한 시장 변동성
# * 도시 재개발 및 재건축으로 인한 신규 주택 공급 확대

# %%
# 랭체인용 os모듈 적용
import os
os.environ['GOOGLE_API_KEY'] = 'AIzaSyBJep_00dpD76qfo-sbFzaR19T2KcF5YVk'

# %%
#랭체인으로 전환
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-pro",
                             temperature=0.7)
result = model.invoke("한국 서울 주택 시장 동향에 대해서 도표로 알려주세요")
Markdown(result.content)
# Out:
# **서울 주택 시장 동향 도표**
#
# **아파트 가격:**
#
# * [그림 1] 서울 주요 지역 아파트 평균 가격 추이
#
# **건설 매물 수:**
#
# * [그림 2] 서울 건설 매물 수 추이
#
# **매매 거래량:**
#
# * [그림 3] 서울 아파트 매매 거래량 추이
#
# **전세 가격:**
#
# * [그림 4] 서울 주요 지역 전세 가격 추이
#
# **전세 수익률:**
#
# * [그림 5] 서울 전세 수익률 추이
#
# **임대료:**
#
# * [그림 6] 서울 주요 지역 임대료 추이
#
# **공급량:**
#
# * [그림 7] 서울 주택 공급량 추이
#
# **수요:**
#
# * [그림 8] 서울 주택 수요 추이
#
# **정책적 영향:**
#
# * [그림 9] 서울 주택 정책적 영향
#
# **참고:**
#
# * 그림은 대표적인 자료를 기반으로 작성되었으며, 실제 시장 상황과 다를 수 있습니다.
# * 가격은 평균값이며 지역이나 물건 유형에 따라 차이가 있을 수 있습니다.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(pages)

from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

docsearch = Chroma.from_documents(texts, hf)
# Out:
# invalid pdf header: b'\xd0\xcf\x11\xe0\xa1'
# EOF marker not found
# ---------------------------------------------------------------------------
# PdfStreamError                            Traceback (most recent call last)
# Cell In[70], line 2
#       1 loader = PyPDFLoader("/Users/jaehyeongpark/Documents/공동도급 현장 연도별 업무내용 리스트.xls")
# ----> 2 pages = loader.load_and_split()
#       4 text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
#       5 texts = text_splitter.split_documents(pages)
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_community/document_loaders/base.py:51, in BaseLoader.load_and_split(self, text_splitter)
#      49 else:
#      50     _text_splitter = text_splitter
# ---> 51 docs = self.load()
#      52 return _text_splitter.split_documents(docs)
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_community/document_loaders/pdf.py:162, in PyPDFLoader.load(self)
#     160 def load(self) -> List[Document]:
#     161     """Load given path as pages."""
# --> 162     return list(self.lazy_load())
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_community/document_loaders/pdf.py:172, in PyPDFLoader.lazy_load(self)
#     170 else:
#     171     blob = Blob.from_path(self.file_path)
# --> 172 yield from self.parser.parse(blob)
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_community/document_loaders/base.py:111, in BaseBlobParser.parse(self, blob)
#      96 def parse(self, blob: Blob) -> List[Document]:
#      97     """Eagerly parse the blob into a document or documents.
#      98
#      99     This is a convenience method for interactive development environment.
#    (...)
#     109         List of documents
#     110     """
# --> 111     return list(self.lazy_parse(blob))
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_community/document_loaders/parsers/pdf.py:94, in PyPDFParser.lazy_parse(self, blob)
#      91 import pypdf
#      93 with blob.as_bytes_io() as pdf_file_obj:
# ---> 94     pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
#      95     yield from [
#      96         Document(
#      97             page_content=page.extract_text()
#    (...)
#     101         for page_number, page in enumerate(pdf_reader.pages)
#     102     ]
#
# File /opt/homebrew/lib/python3.11/site-packages/pypdf/_reader.py:318, in PdfReader.__init__(self, stream, strict, password)
#     316     with open(stream, "rb") as fh:
#     317         stream = BytesIO(fh.read())
# --> 318 self.read(stream)
#     319 self.stream = stream
#     321 self._override_encryption = False
#
# File /opt/homebrew/lib/python3.11/site-packages/pypdf/_reader.py:1335, in PdfReader.read(self, stream)
#    1333 def read(self, stream: StreamType) -> None:
#    1334     self._basic_validation(stream)
# -> 1335     self._find_eof_marker(stream)
#    1336     startxref = self._find_startxref_pos(stream)
#    1338     # check and eventually correct the startxref only in not strict
#
# File /opt/homebrew/lib/python3.11/site-packages/pypdf/_reader.py:1406, in PdfReader._find_eof_marker(self, stream)
#    1404     else:
#    1405         logger_warning("EOF marker not found", __name__)
# -> 1406 line = read_previous_line(stream)
#
# File /opt/homebrew/lib/python3.11/site-packages/pypdf/_utils.py:285, in read_previous_line(stream)
#     283 found_crlf = False
#     284 if stream.tell() == 0:
# --> 285     raise PdfStreamError(STREAM_TRUNCATED_PREMATURELY)
#     286 while True:
#     287     to_read = min(DEFAULT_BUFFER_SIZE, stream.tell())
#
# PdfStreamError: Stream has ended unexpectedly

# %%
search = input()

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents(search)
# Out:
# [Document(page_content='• 매니저 UI 관리자 화면 시험• 클라우드 서비스 기능(K8S/MSA)\n  가용성 시험 (공인시험성적서 )[표 3] 연구개발성과의 지표 및 목표\n*평가는 KOLAS 인증 공인기관의 시험성적서를 원칙으로 함 \n[정량적 목표 항목의 평가방법 및 평가환경 ] \n  o 사전 시험환경 및 조건(클라우드 )\n- 시험환경 : 사전 시험 환경 구성을 위해 전술한 형상대로 클라우드 기반환경을 제공과 비용절감을   \n위해 지능정보사회진흥원 (NIA)의 인공지능 LAB 센터의 클라우드 오픈스택을 지원받고 국가시\n험망(KOREN)의 망을 각 공동 및 참여사 별로 시스템을 네트워크로 연결하여 물리적 통신이 \n가능한 형태로 구성하고 M3P-Policer 모듈을 각 시스템 상에 설치. 이후 AI/빅데이터 플랫폼 \n서비스에 따른 정책제어 Flow table의 탑재를 위한 테스트베드 시험환경을 구성\n- 시험조건  : 내부적으로는 네트워크 품질 정보를 수집을 위해 IPFIX를 적용하고 저장하기 위한', metadata={'page': 19, 'source': '/Users/jaehyeongpark/Documents/testfile/test_moon.pdf'}),
#  Document(page_content='파라미터 수집과 분석을 위한 빅데이터 구축 그리고 최적의 경로 예측 강화와 \n정책제어의 신뢰성을 높이기 위한 ”클라우드 기반 실시간 경로 최적화 AI∙빅\n데이터 플랫폼 서비스 제공을 위한 공동사업모델 구축“ 임\n[그림 1] ABC 플랫폼 솔루션 개념도 \n[1단계-1차 연도 목표]\n - 클라우드 인프라 설계 및 구축과 MMMP 시스템 성능 부분 개선', metadata={'page': 2, 'source': '/Users/jaehyeongpark/Documents/testfile/test_moon.pdf'}),
#  Document(page_content='- 17 -   ② 개발 내용 및 범위   \n[문엔지니어링 ]\no Cloud 인프라 설계(리소스 Pool) 구축\n\xa0 오픈스택의 클라우드 자원생성과 관리 패키지 Heat 서비스 제공 \n[그림 17] 클라우드 운영 인프라 구성도\no MMMP 시스템 부분 개선\n- GPU 및 L2→L3 스위칭 교체 및 광회선 추가\n\xa0 KOREN의 클라우드 인프라 제공범위는 오픈스택 \n\xa0 기존의 KOREN(국가시험망 ) 테스트베드의 광 1회선을 2회선으로 증설\n[그림 18] 클라우드 오픈스택 제공 KOREN 구성도', metadata={'page': 26, 'source': '/Users/jaehyeongpark/Documents/testfile/test_moon.pdf'})]

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """Answer the question as based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x["question"]),
    "question": lambda x: x["question"]
}) | prompt | model

# %%
print(chain.invoke({'question': search}).content)
# Out:
# 제공된 텍스트에는 클라우드 가상자원 성능 측정에 대한 정보가 포함되어 있지 않습니다.

# %% [markdown]
# RAG의 장점 : 명확한 대답과 증거를 제시한다.
# RAG의 단점 : 정확하게 물어보지 않으면 대답을 잘 해주지 않는다
